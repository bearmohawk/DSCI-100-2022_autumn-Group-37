# %% [markdown]
# **Welcome to the project Notebook!!!**
#
# We'll be writing stuff here. Please add this to your Jupyters.

# %%
library(tidyverse)
library(dplyr)
library(readxl)

url <- "https://github.com/bearmohawk/DSCI-100-2022_autumn-Group-37/blob/e50b948ca76c639c1fd0c889e7378b8cc5d9ff28/data/Maths.csv"

destfile <- "data/Maths.csv"
download.file(url, destfile)

data <- read_csv(destfile)
# Out:
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 15493 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): <!DOCTYPE html>
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
problems(x = .Last.value)

stop_for_problems(x)
# Out:
#    row   col expected  actual
# 1   16   367 1 columns 367 columns
# 2   56     3 1 columns 3 columns
# 3   77     4 1 columns 4 columns
# 4  112     3 1 columns 3 columns
# 5  120     6 1 columns 6 columns
# 6  148     4 1 columns 4 columns
# 7  158     4 1 columns 4 columns
# 8  168     4 1 columns 4 columns
# 9  178     4 1 columns 4 columns
# 10 188     4 1 columns 4 columns
# 11 198     4 1 columns 4 columns
# 12 208     4 1 columns 4 columns
# 13 218     4 1 columns 4 columns
# 14 231     4 1 columns 4 columns
# 15 235     4 1 columns 4 columns
# 16 242     4 1 columns 4 columns
# 17 249     4 1 columns 4 columns
# 18 269     4 1 columns 4 columns
# 19 273     4 1 columns 4 columns
# 20 277     4 1 columns 4 columns
# 21 284     4 1 columns 4 columns
# 22 291     4 1 columns 4 columns
# 23 298     4 1 columns 4 columns
# 24 308     4 1 columns 4 columns
# 25 312     4 1 columns 4 columns
# 26 331     4 1 columns 4 columns
# 27 340     4 1 columns 4 columns
# ...
